-- %% [markdown]
-- # [dbo].[ConversationMembers]

-- %%
USE [SecureChat]
GO

-- %%
/****** Object:  Table [dbo].[ConversationMembers]    Script Date: 12/28/2025 12:55:38 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConversationMembers](
	[ConversationId] [int] NOT NULL,
	[UserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ConversationId] ASC,
	[UserId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Conversations]

-- %%
/****** Object:  Table [dbo].[Conversations]    Script Date: 12/28/2025 12:55:38 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Conversations](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Title] [nvarchar](100) NULL,
	[CreatedAt] [datetime2](7) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Messages]

-- %%
/****** Object:  Table [dbo].[Messages]    Script Date: 12/28/2025 12:55:38 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Messages](
	[Id] [bigint] IDENTITY(1,1) NOT NULL,
	[ConversationId] [int] NOT NULL,
	[SenderId] [int] NOT NULL,
	[Body] [nvarchar](max) NOT NULL,
	[BodyHash] [varbinary](32) NOT NULL,
	[Signature] [varbinary](max) NOT NULL,
	[ClientTimestamp] [datetime2](7) NULL,
	[CreatedAt] [datetime2](7) NOT NULL,
	[Nonce] [varbinary](16) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 12/28/2025 12:55:38 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Username] [nvarchar](50) NOT NULL,
	[Salt] [varbinary](32) NOT NULL,
	[Iterations] [int] NOT NULL,
	[PasswordHash] [varbinary](32) NOT NULL,
	[PublicKeyPem] [nvarchar](max) NOT NULL,
	[CreatedAt] [datetime2](7) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConversationMembers]

-- %%
INSERT [dbo].[ConversationMembers] ([ConversationId], [UserId]) VALUES (13, 19)
GO

-- %% [markdown]
-- # [dbo].[Conversations]

-- %%
SET IDENTITY_INSERT [dbo].[Conversations] ON 
INSERT [dbo].[Conversations] ([Id], [Title], [CreatedAt]) VALUES (13, N'New chat', CAST(N'2025-12-27T06:27:31.1471884' AS DateTime2))
SET IDENTITY_INSERT [dbo].[Conversations] OFF
GO

-- %% [markdown]
-- # [dbo].[Messages]

-- %%
SET IDENTITY_INSERT [dbo].[Messages] ON 
INSERT [dbo].[Messages] ([Id], [ConversationId], [SenderId], [Body], [BodyHash], [Signature], [ClientTimestamp], [CreatedAt], [Nonce]) VALUES (16, 13, 19, N'hello', 0xE7A46AF1EDB8B60D60D261B5F4E74718E67788E9777F42B2227BCC105194D4AD, ..., CAST(N'2025-12-27T06:27:46.2920000' AS DateTime2), CAST(N'2025-12-27T06:27:46.3202227' AS DateTime2), 0xC71E266B025B7773D3FB10201F157CA7)
SET IDENTITY_INSERT [dbo].[Messages] OFF
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
SET IDENTITY_INSERT [dbo].[Users] ON 
INSERT [dbo].[Users] ([Id], [Username], [Salt], [Iterations], [PasswordHash], [PublicKeyPem], [CreatedAt]) VALUES (12, N'admin', 0x2682913C12D71831FE4C08237D689493, 150000, 0x6F4279684772CE8F942B73B913CF0A166B647A5A0144B499EF01D8D0EF826C94, N'-----BEGIN PUBLIC KEY-----

nwIDAQAB
-----END PUBLIC KEY-----', CAST(N'2025-12-24T08:27:29.5681772' AS DateTime2))
INSERT [dbo].[Users] ([Id], [Username], [Salt], [Iterations], [PasswordHash], [PublicKeyPem], [CreatedAt]) VALUES (19, N'Bao', 0x27862508E088E8DAC34F70621719A558, 150000, 0x5835D0A2DF5DCCAF1BC31190F4BA5DCD03105EDCA4C93456E415C9DB08531761, N'-----BEGIN PUBLIC KEY-----

0QIDAQAB
-----END PUBLIC KEY-----', CAST(N'2025-12-27T06:26:12.5450656' AS DateTime2))
INSERT [dbo].[Users] ([Id], [Username], [Salt], [Iterations], [PasswordHash], [PublicKeyPem], [CreatedAt]) VALUES (21, N'Hoang', 0x23E8C8F7C00B0352156CFA4663282440, 150000, 0x2E43330B6F68312165A8B3E05A1FF49AE5CC96843D422F712145DBBC41F76764, N'-----BEGIN PUBLIC KEY-----

ZwIDAQAB
-----END PUBLIC KEY-----', CAST(N'2025-12-28T04:50:40.2973884' AS DateTime2))
SET IDENTITY_INSERT [dbo].[Users] OFF
GO

-- %% [markdown]
-- # [UQ__Users__536C85E48F4CED02]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__Users__536C85E48F4CED02]    Script Date: 12/28/2025 12:55:38 PM ******/
ALTER TABLE [dbo].[Users] ADD UNIQUE NONCLUSTERED 
(
	[Username] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Conversat__Creat__4D94879B]

-- %%
ALTER TABLE [dbo].[Conversations] ADD  DEFAULT (sysutcdatetime()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Messages__Create__5441852A]

-- %%
ALTER TABLE [dbo].[Messages] ADD  DEFAULT (sysutcdatetime()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [DF__Users__CreatedAt__4AB81AF0]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (sysutcdatetime()) FOR [CreatedAt]
GO

-- %% [markdown]
-- # [FK_CM_Conv]

-- %%
ALTER TABLE [dbo].[ConversationMembers]  WITH CHECK ADD  CONSTRAINT [FK_CM_Conv] FOREIGN KEY([ConversationId])
REFERENCES [dbo].[Conversations] ([Id])
GO
ALTER TABLE [dbo].[ConversationMembers] CHECK CONSTRAINT [FK_CM_Conv]
GO

-- %% [markdown]
-- # [FK_CM_User]

-- %%
ALTER TABLE [dbo].[ConversationMembers]  WITH CHECK ADD  CONSTRAINT [FK_CM_User] FOREIGN KEY([UserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[ConversationMembers] CHECK CONSTRAINT [FK_CM_User]
GO

-- %% [markdown]
-- # [FK_M_Conv]

-- %%
ALTER TABLE [dbo].[Messages]  WITH CHECK ADD  CONSTRAINT [FK_M_Conv] FOREIGN KEY([ConversationId])
REFERENCES [dbo].[Conversations] ([Id])
GO
ALTER TABLE [dbo].[Messages] CHECK CONSTRAINT [FK_M_Conv]
GO

-- %% [markdown]
-- # [FK_M_Sender]

-- %%
ALTER TABLE [dbo].[Messages]  WITH CHECK ADD  CONSTRAINT [FK_M_Sender] FOREIGN KEY([SenderId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Messages] CHECK CONSTRAINT [FK_M_Sender]
GO
